# %%
from src.char_map import char_map, index_map
from src.models import model_2

model = model_2(input_dim=13,
                filters=200,
                kernel_size=11, 
                conv_stride=2,
                conv_border_mode='valid',
                units=250,
                activation='relu',
                dropout_rate=1,
                number_of_layers=5,
                output_dim=len(char_map)+1)
model_name = "model_2_overfit"
model.load_weights('models/' + model_name + '.h5')
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 13)          0
# _________________________________________________________________
# layer_1_conv (Conv1D)        (None, None, 200)         28800
# _________________________________________________________________
# conv_batch_norm (BatchNormal (None, None, 200)         800
# _________________________________________________________________
# rnn_1 (GRU)                  (None, None, 250)         338250
# _________________________________________________________________
# bt_rnn_1 (BatchNormalization (None, None, 250)         1000
# _________________________________________________________________
# rnn_2 (GRU)                  (None, None, 250)         375750
# _________________________________________________________________
# bt_rnn_2 (BatchNormalization (None, None, 250)         1000
# _________________________________________________________________
# rnn_3 (GRU)                  (None, None, 250)         375750
# _________________________________________________________________
# bt_rnn_3 (BatchNormalization (None, None, 250)         1000
# _________________________________________________________________
# rnn_4 (GRU)                  (None, None, 250)         375750
# _________________________________________________________________
# bt_rnn_4 (BatchNormalization (None, None, 250)         1000
# _________________________________________________________________
# final_layer_of_rnn (GRU)     (None, None, 250)         375750
# _________________________________________________________________
# bt_rnn_final (BatchNormaliza (None, None, 250)         1000
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, None, 224)         56224
# _________________________________________________________________
# softmax (Activation)         (None, None, 224)         0
# =================================================================
# Total params: 1,932,074
# Trainable params: 1,929,174
# Non-trainable params: 2,900
# _________________________________________________________________
# None

# %%
from src.plot import plot_hist

model_name = "model_2_overfit"
plot_hist(model_name)

# %%
import numpy as np
import pickle
from src.predict import predict

predict(0, 'train', model)
predict(1, 'train', model)
predict(2, 'train', model)
predict(3, 'train', model)
predict(4, 'train', model)
predict(5, 'train', model)
predict(6, 'train', model)
predict(7, 'train', model)
predict(8, 'train', model)
predict(9, 'train', model)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ያንደኛ ደረጃ ትምህርታቸው ን ጐንደር ተ ም ረዋል
# Predicted: ያንደኛ ደረጃ ትምህር ታቸው ን ጐንደር ተም ረዋል
# wer: 2
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ወሬው ን ወሬ ያደረጉ ምስጢረ ኞች ናቸው
# Predicted: ወሬ ው ወሬ ያደረጉ ምስጢረ ኞች ናቸው
# wer: 2
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ኢትዮጵያዊ ቷ በ ብሄራዊ ባህላዊ አለባበስ ከ አለም አንደኝነት ን ተቀዳጀ ች
# Predicted: ኢትዮጵያዊቶ በ ቢዬራ ዊ በ ህላዊየ አለባበስ ከ አለ አንደኝነት ን ተቀዳጄች
# wer: 11
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ከ ትምክህት እንዳይ ቆጠር ብን እንጂ በ አለም ታሪክ ውስጥ በ ነጮች ያል ተረገጠ ች አገር ኢትዮጵያ ና ት
# Predicted: ከትም ክህት እንዳይ ቆጠር ብን እንጂ በ አለም ታሪክ ውስጥ በ ኔጮች ያልተረገጠ ች አገል ኢትዮጵያ ና ት
# wer: 5
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: እህቶቹ የኤርትራ ዜጐች ና የ ሻእቢያ ደጋፊዎች ናቸው
# Predicted: እህቱቹ የኤርትራዘጐች ና የ ሻእቢያ ደጋፊ ዎች ና ቸው
# wer: 5
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: እናንተ ም መቀበሪያ እንዳ ታጡ ተጠንቀቁ
# Predicted: እናንተም መቀበሪያ እንዳታዱ ተጠንቀቁ
# wer: 3
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: አንቶኔሊ በ አጼ ምንሊክ ፊት የ ፈጸመው ድፍረት በ ኢጣሊያ ን ምክር ቤት አስተ ቸው
# Predicted: አንቶ ኖ ሊ ቫ ያጼ ምን ሊክ ፊት የፈጸያውዶፍረ እኢጣሊ ምርክር ቤት አስተቸው
# wer: 18
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ከ ማወቁ በፊት እንደ ተበጠበጠ ገበያ እንዳይ በታተን ይህ ነው አጀንዳ ችን ሌላ አጀንዳ የ ለ ንም
# Predicted: ከ ማወቁ በ ፊት እንደ ተብጠበጠ ገበያ እንዳይ በታተ ን የህነው አጀ ንዳችን ሌላ አጀንዳ የለ ን ም
# wer: 9
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ኢትዮጵያ ም ሰራዊቷ በ ኤርትራ እንደሚ ገኝ አል ካደ ችም
# Predicted: ኢትዮጵያ ም ሰራዊቷ በ ኤርትራ እንደሚገኝ አል ካደ ች ም
# wer: 2
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Truth: ላቁኦተ ትምህርት ቤት መንገድ ና ሆስፒታል ተ ገንብቷል
# Predicted: ላቁኦተት ምህርት ቤት መንገድና ሆስቢታል ተገንብቷል
# wer: 5
# 5
