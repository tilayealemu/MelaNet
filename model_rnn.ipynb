# %%
from src.char_map import char_map, index_map
from src.models import rnn_model

model = rnn_model(input_dim=13,
                  units=2,
                  activation='relu',
                  output_dim=len(char_map)+1)
model_name = "rnn"
model.load_weights('models/' + model_name + '.h5')
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# the_input (InputLayer)       (None, None, 13)          0
# _________________________________________________________________
# rnn (GRU)                    (None, None, 2)           96
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 2)           8
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, None, 224)         672
# _________________________________________________________________
# softmax (Activation)         (None, None, 224)         0
# ...
# Total params: 776
# Trainable params: 772
# Non-trainable params: 4
# _________________________________________________________________
# None

# %%
from src.train import train

train(input_to_softmax=model, model_name=model_name, spectrogram=False, epochs=2)
# Out:
# Epoch 1/2
# 5/5 [==============================] - 20s 4s/step - loss: 2973.3158 - val_loss: 1841.8391
# Epoch 2/2
# 5/5 [==============================] - 18s 4s/step - loss: 1499.8257 - val_loss: 384.9880

# %%
from src.predict import predict
# %matplotlib inline

predict(1, 'train', model)
# Out:
# True transcription:
#
# ወሬው ን ወሬ ያደረጉ ምስጢረ ኞች ናቸው
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# ም
# --------------------------------------------------------------------------------
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 24

# %%
predict(0, 'train', model, verbose=False)
# Out:
# 31

# %%
predict(2, 'train', model)
# Out:
# True transcription:
#
# ኢትዮጵያዊ ቷ በ ብሄራዊ ባህላዊ አለባበስ ከ አለም አንደኝነት ን ተቀዳጀ ች
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# ራ
# --------------------------------------------------------------------------------
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 47

# %%
predict(3, 'train', model)
# Out:
# True transcription:
#
# ከ ትምክህት እንዳይ ቆጠር ብን እንጂ በ አለም ታሪክ ውስጥ በ ነጮች ያል ተረገጠ ች አገር ኢትዮጵያ ና ት
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# ራ
# --------------------------------------------------------------------------------
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 67

# %%
from src.predict import VALID_LENGTH
from src.predict import predict

for index in range(VALID_LENGTH):
    wer = predict(index, 'train', model, verbose=False)
    print(wer)
# Out:
# 31
# 24
# 47
# 67
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-2-d6dd64aa4cd8> in <module>
#       3
#       4 for index in range(VALID_LENGTH):
# ----> 5     wer = predict(index, 'train', model, verbose=False)
#       6     print(wer)
#
# /notebooks/src/predict.py in predict(index, partition, model, verbose)
#      42     output_length = [model.output_length(data_point.shape[0])]
#      43     pred_ints = (K.eval(K.ctc_decode(
# ---> 44                 prediction, output_length, greedy=False)[0][0])+1).flatten().tolist()
#      45     predicted = ''.join(int_sequence_to_text(pred_ints))
#      46     if verbose:
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in ctc_decode(y_pred, input_length, greedy, beam_width, top_paths)
#    4301
#    4302     decoded_dense = [tf.sparse_to_dense(st.indices, st.dense_shape, st.values, default_value=-1)
# -> 4303                      for st in decoded]
# ...
